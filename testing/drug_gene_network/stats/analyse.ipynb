# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

# %%
jacc = pd.read_csv('jaccard_indices.csv')
cos = pd.read_csv('embedding_similarity.csv')
stats = jacc.merge(cos, on=['drug1', 'drug2'])
stats
# Out:
#               drug1         drug2  weighted_jaccard  normalised_jaccard  \
# 0      CID000005291  CID000004212          0.441903            0.526378
# 1      CID000005291  CID005329102          0.375993            0.430565
# 2      CID000005291  CID003062316          0.377514            0.487868
# 3      CID000005291  CID000176870          0.152332            0.203302
# 4      CID000005291  CID000123631          0.131880            0.192649
# ...             ...           ...               ...                 ...
# 19694  CID000130881  CID005353980          0.470588            0.426667
# 19695  CID000130881  CID000000191          0.000000            0.000000
# 19696  CID003002190  CID000000191          0.000000            0.000000
# 19697  CID005353980  CID000000191          0.000000            0.000000
# 19698  CID005311297  CID000000191          0.000000            0.000000
#
#        binary_jaccard  cosine_sim   euc_dist  cosine_head  cosine_tail
# ...

# %% [markdown]
# # Jaccard index of the weighted projection network

# %%
x = 'weighted_jaccard'
y = 'cosine_sim'
corr = pearsonr(stats[x], stats[y])
sns.scatterplot(data=stats, x=x, y=y)
plt.title(f'{y.replace("_", " ")} vs {x.replace("_", " ")}. Corr = {round(corr[0], 3)} ')
plt.show()

# %%
x = 'weighted_jaccard'
y = 'euc_dist'
corr = pearsonr(stats[x], stats[y])
sns.scatterplot(data=stats, x=x, y=y)
plt.title(f'{y.replace("_", " ")} vs {x.replace("_", " ")}. Corr = {round(corr[0], 3)} ')
plt.show()

# %%
x = 'weighted_jaccard'
y = 'cosine_head'
corr = pearsonr(stats[x], stats[y])
sns.scatterplot(data=stats, x=x, y=y)
plt.title(f'{y.replace("_", " ")} vs {x.replace("_", " ")}. Corr = {round(corr[0], 3)} ')
plt.show()

# %%
x = 'weighted_jaccard'
y = 'cosine_tail'
corr = pearsonr(stats[x], stats[y])
sns.scatterplot(data=stats, x=x, y=y)
plt.title(f'{y.replace("_", " ")} vs {x.replace("_", " ")}. Corr = {round(corr[0], 3)} ')
plt.show()

# %% [markdown]
# # Jaccard index of the normalised weighted network

# %%
x = 'normalised_jaccard'
y = 'cosine_sim'
corr = pearsonr(stats[x], stats[y])
sns.scatterplot(data=stats, x=x, y=y)
plt.title(f'{y.replace("_", " ")} vs {x.replace("_", " ")}. Corr = {round(corr[0], 3)} ')
plt.show()

# %%
x = 'normalised_jaccard'
y = 'euc_dist'
corr = pearsonr(stats[x], stats[y])
sns.scatterplot(data=stats, x=x, y=y)
plt.title(f'{y.replace("_", " ")} vs {x.replace("_", " ")}. Corr = {round(corr[0], 3)} ')
plt.show()

# %%
x = 'normalised_jaccard'
y = 'cosine_head'
corr = pearsonr(stats[x], stats[y])
sns.scatterplot(data=stats, x=x, y=y)
plt.title(f'{y.replace("_", " ")} vs {x.replace("_", " ")}. Corr = {round(corr[0], 3)} ')
plt.show()

# %%
x = 'normalised_jaccard'
y = 'cosine_tail'
corr = pearsonr(stats[x], stats[y])
sns.scatterplot(data=stats, x=x, y=y)
plt.title(f'{y.replace("_", " ")} vs {x.replace("_", " ")}. Corr = {round(corr[0], 3)} ')
plt.show()

# %% [markdown]
# # jaccard index of the binary network projection

# %%
x = 'binary_jaccard'
y = 'cosine_sim'
corr = pearsonr(stats[x], stats[y])
sns.scatterplot(data=stats, x=x, y=y)
plt.title(f'{y.replace("_", " ")} vs {x.replace("_", " ")}. Corr = {round(corr[0], 3)} ')
plt.show()

# %%
x = 'binary_jaccard'
y = 'euc_dist'
corr = pearsonr(stats[x], stats[y])
sns.scatterplot(data=stats, x=x, y=y)
plt.title(f'{y.replace("_", " ")} vs {x.replace("_", " ")}. Corr = {round(corr[0], 3)} ')
plt.show()
